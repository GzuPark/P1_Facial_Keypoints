# %% [markdown]
# ## Define the Convolutional Neural Network
#
# After you've looked at the data you're working with and, in this case, know the shapes of the images and of the keypoints, you are ready to define a convolutional neural network that can *learn* from this data.
#
# In this notebook and in `models.py`, you will:
# 1. Define a CNN with images as input and keypoints as output
# 2. Construct the transformed FaceKeypointsDataset, just as before
# 3. Train the CNN on the training data, tracking loss
# 4. See how the trained model performs on test data
# 5. If necessary, modify the CNN structure and model hyperparameters, so that it performs *well* **\***
#
# **\*** What does *well* mean?
#
# "Well" means that the model's loss decreases during training **and**, when applied to test image data, the model produces keypoints that closely match the true keypoints of each face. And you'll see examples of this later in the notebook.
#
# ---

# %% [markdown]
# ## CNN Architecture
#
# Recall that CNN's are defined by a few types of layers:
# * Convolutional layers
# * Maxpooling layers
# * Fully-connected layers
#
# You are required to use the above layers and encouraged to add multiple convolutional layers and things like dropout layers that may prevent overfitting. You are also encouraged to look at literature on keypoint detection, such as [this paper](https://arxiv.org/pdf/1710.00977.pdf), to help you determine the structure of your network.
#
#
# ### TODO: Define your model in the provided file `models.py` file
#
# This file is mostly empty but contains the expected name and some TODO's for creating your model.
#
# ---

# %% [markdown]
# ## PyTorch Neural Nets
#
# To define a neural network in PyTorch, you define the layers of a model in the function `__init__` and define the feedforward behavior of a network that employs those initialized layers in the function `forward`, which takes in an input image tensor, `x`. The structure of this Net class is shown below and left for you to fill in.
#
# Note: During training, PyTorch will be able to perform backpropagation by keeping track of the network's feedforward behavior and using autograd to calculate the update to the weights in the network.
#
# #### Define the Layers in ` __init__`
# As a reminder, a conv/pool layer may be defined like this (in `__init__`):
# ```
# # 1 input image channel (for grayscale images), 32 output channels/feature maps, 3x3 square convolution kernel
# self.conv1 = nn.Conv2d(1, 32, 3)
#
# # maxpool that uses a square window of kernel_size=2, stride=2
# self.pool = nn.MaxPool2d(2, 2)
# ```
#
# #### Refer to Layers in `forward`
# Then referred to in the `forward` function like this, in which the conv1 layer has a ReLu activation applied to it before maxpooling is applied:
# ```
# x = self.pool(F.relu(self.conv1(x)))
# ```
#
# Best practice is to place any layers whose weights will change during the training process in `__init__` and refer to them in the `forward` function; any layers or functions that always behave in the same way, such as a pre-defined activation function, should appear *only* in the `forward` function.

# %% [markdown]
# #### Why models.py
#
# You are tasked with defining the network in the `models.py` file so that any models you define can be saved and loaded by name in different notebooks in this project directory. For example, by defining a CNN class called `Net` in `models.py`, you can then create that same architecture in this and other notebooks by simply importing the class and instantiating a model:
# ```
#     from models import Net
#     net = Net()
# ```

# %%
# import the usual resources
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# watch for any changes in model.py, if it changes, re-load it automatically
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
## TODO: Define the Net in models.py

import torch
import torch.nn as nn
import torch.nn.functional as F

## TODO: Once you've define the network, you can instantiate it
# one example conv layer has been provided for you
from models import Net

net = Net()
print(net)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1))
#   (conv4): Conv2d(128, 256, kernel_size=(5, 5), stride=(1, 1))
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout1): Dropout2d(p=0.5)
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout2): Dropout2d(p=0.5)
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout3): Dropout2d(p=0.5)
#   (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout4): Dropout2d(p=0.5)
#   (fc1): Linear(in_features=25600, out_features=1000, bias=True)
#   (dropout5): Dropout2d(p=0.5)
#   (fc2): Linear(in_features=1000, out_features=136, bias=True)
# )

# %% [markdown]
# ## Transform the dataset
#
# To prepare for training, create a transformed dataset of images and keypoints.
#
# ### TODO: Define a data transform
#
# In PyTorch, a convolutional neural network expects a torch image of a consistent size as input. For efficient training, and so your model's loss does not blow up during training, it is also suggested that you normalize the input images and keypoints. The necessary transforms have been defined in `data_load.py` and you **do not** need to modify these; take a look at this file (you'll see the same transforms that were defined and applied in Notebook 1).
#
# To define the data transform below, use a [composition](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html#compose-transforms) of:
# 1. Rescaling and/or cropping the data, such that you are left with a square image (the suggested size is 224x224px)
# 2. Normalizing the images and keypoints; turning each RGB image into a grayscale image with a color range of [0, 1] and transforming the given keypoints into a range of [-1, 1]
# 3. Turning these images and keypoints into Tensors
#
# These transformations have been defined in `data_load.py`, but it's up to you to call them and create a `data_transform` below. **This transform will be applied to the training data and, later, the test data**. It will change how you go about displaying these images and keypoints, but these steps are essential for efficient training.
#
# As a note, should you want to perform data augmentation (which is optional in this project), and randomly rotate or shift these images, a square image size will be useful; rotating a 224x224 image by 90 degrees will result in the same shape of output.

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# the dataset we created in Notebook 1 is copied in the helper file `data_load.py`
from data_load import FacialKeypointsDataset
# the transforms we defined in Notebook 1 are in the helper file `data_load.py`
from data_load import Rescale, RandomCrop, Normalize, ToTensor


## TODO: define the data_transform using transforms.Compose([all tx's, . , .])
# order matters! i.e. rescaling should come before a smaller crop
data_transform = transforms.Compose([
                                     Rescale(250),
                                     RandomCrop(224),
                                     Normalize(),
                                     ToTensor()
                                    ])

# testing that you've defined a transform
assert(data_transform is not None), 'Define a data_transform'

# %%
# create the transformed dataset
transformed_dataset = FacialKeypointsDataset(csv_file='data/training_frames_keypoints.csv',
                                             root_dir='data/training/',
                                             transform=data_transform)


print('Number of images: ', len(transformed_dataset))

# iterate through the transformed dataset and print some stats about the first few samples
for i in range(4):
    sample = transformed_dataset[i]
    print(i, sample['image'].size(), sample['keypoints'].size())
# Out:
# Number of images:  3462
# 0 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 1 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 2 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 3 torch.Size([1, 224, 224]) torch.Size([68, 2])

# %% [markdown]
# ## Batching and loading data
#
# Next, having defined the transformed dataset, we can use PyTorch's DataLoader class to load the training data in batches of whatever size as well as to shuffle the data for training the model. You can read more about the parameters of the DataLoader, in [this documentation](http://pytorch.org/docs/master/data.html).
#
# #### Batch size
# Decide on a good batch size for training your model. Try both small and large batch sizes and note how the loss decreases as the model trains.
#
# **Note for Windows users**: Please change the `num_workers` to 0 or you may face some issues with your DataLoader failing.

# %%
# load training data in batches
batch_size = 32

train_loader = DataLoader(transformed_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Before training
#
# Take a look at how this model performs before it trains. You should see that the keypoints it predicts start off in one spot and don't match the keypoints on a face at all! It's interesting to visualize this behavior so that you can compare it to the model after training and see how the model has improved.
#
# #### Load in the test dataset
#
# The test dataset is one that this model has *not* seen before, meaning it has not trained with these images. We'll load in this test data and before and after training, see how your model performs on this set!
#
# To visualize this test data, we have to go through some un-transformation steps to turn our images into python images from tensors and to turn our keypoints back into a recognizable range.

# %%
# load in the test data, using the dataset class
# AND apply the data_transform you defined above

# create the test dataset
test_dataset = FacialKeypointsDataset(csv_file='data/test_frames_keypoints.csv',
                                             root_dir='data/test/',
                                             transform=data_transform)

# %%
# load test data in batches
batch_size = 16

test_loader = DataLoader(test_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Apply the model on a test sample
#
# To test the model on a test sample of data, you have to follow these steps:
# 1. Extract the image and ground truth keypoints from a sample
# 2. Make sure the image is a FloatTensor, which the model expects.
# 3. Forward pass the image through the net to get the predicted, output keypoints.
#
# This function test how the network performs on the first batch of test data. It returns the images, the transformed images, the predicted keypoints (produced by the model), and the ground truth keypoints.

# %%
# test the model on a batch of test images

def net_sample_output():
    
    # iterate through the test dataset
    for i, sample in enumerate(test_loader):
        
        # get sample data: images and ground truth keypoints
        images = sample['image']
        key_pts = sample['keypoints']

        if torch.cuda.is_available():
            images = images.cuda()
            key_pts = key_pts.cuda()
            
        # convert images to FloatTensors
        if torch.cuda.is_available():
            images = images.type(torch.cuda.FloatTensor)
        else:
            images = images.type(torch.FloatTensor)

        # forward pass to get net output
        output_pts = net(images)
        
        # reshape to batch_size x 68 x 2 pts
        output_pts = output_pts.view(output_pts.size()[0], 68, -1)
        
        # break after first image is tested
        if i == 0:
            return images, output_pts, key_pts

# %% [markdown]
# #### Debugging tips
#
# If you get a size or dimension error here, make sure that your network outputs the expected number of keypoints! Or if you get a Tensor type error, look into changing the above code that casts the data into float types: `images = images.type(torch.FloatTensor)`.

# %%
# call the above function
# returns: test images, test predicted keypoints, test ground truth keypoints
test_images, test_outputs, gt_pts = net_sample_output()

# print out the dimensions of the data to see if they make sense
print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([16, 1, 224, 224])
# torch.Size([16, 68, 2])
# torch.Size([16, 68, 2])

# %% [markdown]
# ## Visualize the predicted keypoints
#
# Once we've had the model produce some predicted output keypoints, we can visualize these points in a way that's similar to how we've displayed this data before, only this time, we have to "un-transform" the image/keypoint data to display it.
#
# Note that I've defined a *new* function, `show_all_keypoints` that displays a grayscale image, its predicted keypoints and its ground truth keypoints (if provided).

# %%
def show_all_keypoints(image, predicted_key_pts, gt_pts=None):
    """Show image with predicted keypoints"""
    # image is grayscale
    plt.imshow(image, cmap='gray')
    plt.scatter(predicted_key_pts[:, 0], predicted_key_pts[:, 1], s=20, marker='.', c='m')
    # plot ground truth points as green pts
    if gt_pts is not None:
        plt.scatter(gt_pts[:, 0], gt_pts[:, 1], s=20, marker='.', c='g')

# %% [markdown]
# #### Un-transformation
#
# Next, you'll see a helper function. `visualize_output` that takes in a batch of images, predicted keypoints, and ground truth keypoints and displays a set of those images and their true/predicted keypoints.
#
# This function's main role is to take batches of image and keypoint data (the input and output of your CNN), and transform them into numpy images and un-normalized keypoints (x, y) for normal display. The un-transformation process turns keypoints and images into numpy arrays from Tensors *and* it undoes the keypoint normalization done in the Normalize() transform; it's assumed that you applied these transformations when you loaded your test data.

# %%
# visualize the output
# by default this shows a batch of 10 images
def visualize_output(test_images, test_outputs, gt_pts=None, batch_size=10):

    for i in range(batch_size):
        plt.figure(figsize=(20,10))
        ax = plt.subplot(1, batch_size, i+1)

        # un-transform the image data
        image = test_images[i].data   # get the image from it's wrapper
        if torch.cuda.is_available():
            image = image.cpu().numpy()
        else:
            image = image.numpy()   # convert to numpy array from a Tensor
        image = np.transpose(image, (1, 2, 0))   # transpose to go from torch to numpy image

        # un-transform the predicted key_pts data
        predicted_key_pts = test_outputs[i].data
        if torch.cuda.is_available():
            predicted_key_pts = predicted_key_pts.cpu().numpy()
        else:
            predicted_key_pts = predicted_key_pts.numpy()
        # undo normalization of keypoints  
        predicted_key_pts = predicted_key_pts*50.0+100
        
        # plot ground truth points for comparison, if they exist
        ground_truth_pts = None
        if gt_pts is not None:
            ground_truth_pts = gt_pts[i]         
            ground_truth_pts = ground_truth_pts*50.0+100
        
        # call show_all_keypoints
        show_all_keypoints(np.squeeze(image), predicted_key_pts, ground_truth_pts)
            
        plt.axis('off')

    plt.show()
    
# call it
visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# ## Training
#
# #### Loss function
# Training a network to predict keypoints is different than training a network to predict a class; instead of outputting a distribution of classes and using cross entropy loss, you may want to choose a loss function that is suited for regression, which directly compares a predicted value and target value. Read about the various kinds of loss functions (like MSE or L1/SmoothL1 loss) in [this documentation](http://pytorch.org/docs/master/_modules/torch/nn/modules/loss.html).
#
# ### TODO: Define the loss and optimization
#
# Next, you'll define how the model will train by deciding on the loss function and optimizer.
#
# ---

# %%
## TODO: Define the loss and optimization
import torch.optim as optim

criterion = nn.SmoothL1Loss()

optimizer = torch.optim.Adam(net.parameters(), lr=1e-4)

# %% [markdown]
# ## Training and Initial Observation
#
# Now, you'll train on your batched training data from `train_loader` for a number of epochs.
#
# To quickly observe how your model is training and decide on whether or not you should modify it's structure or hyperparameters, you're encouraged to start off with just one or two epochs at first. As you train, note how your the model's loss behaves over time: does it decrease quickly at first and then slow down? Does it take a while to decrease in the first place? What happens if you change the batch size of your training data or modify your loss function? etc.
#
# Use these initial observations to make changes to your model and decide on the best architecture before you train for many epochs and create a final model.

# %%
def train_net(n_epochs):

    # prepare the net for training
    if torch.cuda.is_available():
        net.cuda()
        print('CUDA: {}\n'.format(torch.cuda.is_available()))
    net.train()

    for epoch in range(n_epochs):  # loop over the dataset multiple times
        
        running_loss = 0.0

        # train on batches of data, assumes you already have train_loader
        for batch_i, data in enumerate(train_loader):
            # get the input images and their corresponding labels
            images = data['image']
            key_pts = data['keypoints']
            
            # cuda
            if torch.cuda.is_available():
                images = images.cuda()
                key_pts = key_pts.cuda()

            # flatten pts
            key_pts = key_pts.view(key_pts.size(0), -1)

            # convert variables to floats for regression loss
            if torch.cuda.is_available():
                key_pts = key_pts.type(torch.cuda.FloatTensor)
                images = images.type(torch.cuda.FloatTensor)
            else:
                key_pts = key_pts.type(torch.FloatTensor)
                images = images.type(torch.FloatTensor)

            # forward pass to get outputs
            output_pts = net(images)

            # calculate the loss between predicted and target keypoints
            loss = criterion(output_pts, key_pts)

            # zero the parameter (weight) gradients
            optimizer.zero_grad()
            
            # backward pass to calculate the weight gradients
            loss.backward()

            # update the weights
            optimizer.step()

            # print loss statistics
            # to convert loss into a scalar and add it to the running_loss, use .item()
            running_loss += loss.item()
            if batch_i % 10 == 9:    # print every 10 batches
                print('Epoch: {}, Batch: {}, Avg. Loss: {:.7f}'.format(epoch + 1, batch_i+1, running_loss/1000))
                running_loss = 0.0

    print('Finished Training')

# %%
# train your network
n_epochs = 10 # start small, and increase when you've decided on your model structure and hyperparams

train_net(n_epochs)
# Out:
# CUDA: True
#
# Epoch: 1, Batch: 10, Avg. Loss: 0.0019144
# Epoch: 1, Batch: 20, Avg. Loss: 0.0014907
# Epoch: 1, Batch: 30, Avg. Loss: 0.0012753
# Epoch: 1, Batch: 40, Avg. Loss: 0.0011852
# Epoch: 1, Batch: 50, Avg. Loss: 0.0012632
# Epoch: 1, Batch: 60, Avg. Loss: 0.0011572
# Epoch: 1, Batch: 70, Avg. Loss: 0.0012914
# Epoch: 1, Batch: 80, Avg. Loss: 0.0012012
# Epoch: 1, Batch: 90, Avg. Loss: 0.0012573
# Epoch: 1, Batch: 100, Avg. Loss: 0.0010510
# Epoch: 2, Batch: 10, Avg. Loss: 0.0010302
# Epoch: 2, Batch: 20, Avg. Loss: 0.0011488
# Epoch: 2, Batch: 30, Avg. Loss: 0.0010748
# Epoch: 2, Batch: 40, Avg. Loss: 0.0011089
# Epoch: 2, Batch: 50, Avg. Loss: 0.0012098
# Epoch: 2, Batch: 60, Avg. Loss: 0.0011074
# Epoch: 2, Batch: 70, Avg. Loss: 0.0010234
# Epoch: 2, Batch: 80, Avg. Loss: 0.0010914
# Epoch: 2, Batch: 90, Avg. Loss: 0.0011335
# Epoch: 2, Batch: 100, Avg. Loss: 0.0011389
# Epoch: 3, Batch: 10, Avg. Loss: 0.0009904
# Epoch: 3, Batch: 20, Avg. Loss: 0.0010826
# Epoch: 3, Batch: 30, Avg. Loss: 0.0010763
# Epoch: 3, Batch: 40, Avg. Loss: 0.0010426
# Epoch: 3, Batch: 50, Avg. Loss: 0.0009933
# Epoch: 3, Batch: 60, Avg. Loss: 0.0009816
# Epoch: 3, Batch: 70, Avg. Loss: 0.0009097
# Epoch: 3, Batch: 80, Avg. Loss: 0.0010121
# Epoch: 3, Batch: 90, Avg. Loss: 0.0010414
# Epoch: 3, Batch: 100, Avg. Loss: 0.0010091
# Epoch: 4, Batch: 10, Avg. Loss: 0.0009504
# Epoch: 4, Batch: 20, Avg. Loss: 0.0009724
# Epoch: 4, Batch: 30, Avg. Loss: 0.0010242
# Epoch: 4, Batch: 40, Avg. Loss: 0.0009475
# Epoch: 4, Batch: 50, Avg. Loss: 0.0009739
# Epoch: 4, Batch: 60, Avg. Loss: 0.0009684
# Epoch: 4, Batch: 70, Avg. Loss: 0.0009181
# Epoch: 4, Batch: 80, Avg. Loss: 0.0010003
# Epoch: 4, Batch: 90, Avg. Loss: 0.0009469
# Epoch: 4, Batch: 100, Avg. Loss: 0.0009479
# Epoch: 5, Batch: 10, Avg. Loss: 0.0009322
# Epoch: 5, Batch: 20, Avg. Loss: 0.0010709
# Epoch: 5, Batch: 30, Avg. Loss: 0.0009449
# Epoch: 5, Batch: 40, Avg. Loss: 0.0009454
# Epoch: 5, Batch: 50, Avg. Loss: 0.0009690
# Epoch: 5, Batch: 60, Avg. Loss: 0.0009881
# Epoch: 5, Batch: 70, Avg. Loss: 0.0009384
# Epoch: 5, Batch: 80, Avg. Loss: 0.0010040
# Epoch: 5, Batch: 90, Avg. Loss: 0.0008963
# Epoch: 5, Batch: 100, Avg. Loss: 0.0009768
# Epoch: 6, Batch: 10, Avg. Loss: 0.0008846
# Epoch: 6, Batch: 20, Avg. Loss: 0.0010659
# Epoch: 6, Batch: 30, Avg. Loss: 0.0008834
# Epoch: 6, Batch: 40, Avg. Loss: 0.0009758
# Epoch: 6, Batch: 50, Avg. Loss: 0.0009331
# Epoch: 6, Batch: 60, Avg. Loss: 0.0009134
# Epoch: 6, Batch: 70, Avg. Loss: 0.0009692
# Epoch: 6, Batch: 80, Avg. Loss: 0.0010286
# Epoch: 6, Batch: 90, Avg. Loss: 0.0008433
# Epoch: 6, Batch: 100, Avg. Loss: 0.0010085
# Epoch: 7, Batch: 10, Avg. Loss: 0.0008636
# Epoch: 7, Batch: 20, Avg. Loss: 0.0008855
# Epoch: 7, Batch: 30, Avg. Loss: 0.0009052
# Epoch: 7, Batch: 40, Avg. Loss: 0.0009614
# Epoch: 7, Batch: 50, Avg. Loss: 0.0010033
# Epoch: 7, Batch: 60, Avg. Loss: 0.0009724
# Epoch: 7, Batch: 70, Avg. Loss: 0.0009833
# Epoch: 7, Batch: 80, Avg. Loss: 0.0010745
# Epoch: 7, Batch: 90, Avg. Loss: 0.0008287
# Epoch: 7, Batch: 100, Avg. Loss: 0.0009632
# Epoch: 8, Batch: 10, Avg. Loss: 0.0008988
# Epoch: 8, Batch: 20, Avg. Loss: 0.0009332
# Epoch: 8, Batch: 30, Avg. Loss: 0.0008384
# Epoch: 8, Batch: 40, Avg. Loss: 0.0008635
# Epoch: 8, Batch: 50, Avg. Loss: 0.0008971
# Epoch: 8, Batch: 60, Avg. Loss: 0.0009290
# Epoch: 8, Batch: 70, Avg. Loss: 0.0009018
# Epoch: 8, Batch: 80, Avg. Loss: 0.0010654
# Epoch: 8, Batch: 90, Avg. Loss: 0.0008634
# Epoch: 8, Batch: 100, Avg. Loss: 0.0009147
# Epoch: 9, Batch: 10, Avg. Loss: 0.0008308
# Epoch: 9, Batch: 20, Avg. Loss: 0.0008735
# Epoch: 9, Batch: 30, Avg. Loss: 0.0008441
# Epoch: 9, Batch: 40, Avg. Loss: 0.0008992
# Epoch: 9, Batch: 50, Avg. Loss: 0.0007988
# Epoch: 9, Batch: 60, Avg. Loss: 0.0009025
# Epoch: 9, Batch: 70, Avg. Loss: 0.0008621
# Epoch: 9, Batch: 80, Avg. Loss: 0.0009212
# Epoch: 9, Batch: 90, Avg. Loss: 0.0007589
# Epoch: 9, Batch: 100, Avg. Loss: 0.0007927
# Epoch: 10, Batch: 10, Avg. Loss: 0.0008035
# Epoch: 10, Batch: 20, Avg. Loss: 0.0007587
# Epoch: 10, Batch: 30, Avg. Loss: 0.0008336
# Epoch: 10, Batch: 40, Avg. Loss: 0.0006619
# Epoch: 10, Batch: 50, Avg. Loss: 0.0007091
# Epoch: 10, Batch: 60, Avg. Loss: 0.0007588
# Epoch: 10, Batch: 70, Avg. Loss: 0.0008313
# Epoch: 10, Batch: 80, Avg. Loss: 0.0008196
# Epoch: 10, Batch: 90, Avg. Loss: 0.0007318
# Epoch: 10, Batch: 100, Avg. Loss: 0.0007521
# Finished Training

# %%
# train your network
n_epochs = 10 # start small, and increase when you've decided on your model structure and hyperparams

train_net(n_epochs)
# Out:
# CUDA: True
#
# Epoch: 1, Batch: 10, Avg. Loss: 0.0007618
# Epoch: 1, Batch: 20, Avg. Loss: 0.0007092
# Epoch: 1, Batch: 30, Avg. Loss: 0.0006827
# Epoch: 1, Batch: 40, Avg. Loss: 0.0006681
# Epoch: 1, Batch: 50, Avg. Loss: 0.0007778
# Epoch: 1, Batch: 60, Avg. Loss: 0.0005739
# Epoch: 1, Batch: 70, Avg. Loss: 0.0005797
# Epoch: 1, Batch: 80, Avg. Loss: 0.0006406
# Epoch: 1, Batch: 90, Avg. Loss: 0.0007053
# Epoch: 1, Batch: 100, Avg. Loss: 0.0006688
# Epoch: 2, Batch: 10, Avg. Loss: 0.0005794
# Epoch: 2, Batch: 20, Avg. Loss: 0.0005961
# Epoch: 2, Batch: 30, Avg. Loss: 0.0005541
# Epoch: 2, Batch: 40, Avg. Loss: 0.0005872
# Epoch: 2, Batch: 50, Avg. Loss: 0.0005111
# Epoch: 2, Batch: 60, Avg. Loss: 0.0006774
# Epoch: 2, Batch: 70, Avg. Loss: 0.0006043
# Epoch: 2, Batch: 80, Avg. Loss: 0.0006527
# Epoch: 2, Batch: 90, Avg. Loss: 0.0005929
# Epoch: 2, Batch: 100, Avg. Loss: 0.0005384
# Epoch: 3, Batch: 10, Avg. Loss: 0.0004834
# Epoch: 3, Batch: 20, Avg. Loss: 0.0006022
# Epoch: 3, Batch: 30, Avg. Loss: 0.0005383
# Epoch: 3, Batch: 40, Avg. Loss: 0.0005188
# Epoch: 3, Batch: 50, Avg. Loss: 0.0006286
# Epoch: 3, Batch: 60, Avg. Loss: 0.0005659
# Epoch: 3, Batch: 70, Avg. Loss: 0.0005207
# Epoch: 3, Batch: 80, Avg. Loss: 0.0004804
# Epoch: 3, Batch: 90, Avg. Loss: 0.0006106
# Epoch: 3, Batch: 100, Avg. Loss: 0.0005522
# Epoch: 4, Batch: 10, Avg. Loss: 0.0004838
# Epoch: 4, Batch: 20, Avg. Loss: 0.0005537
# Epoch: 4, Batch: 30, Avg. Loss: 0.0005306
# Epoch: 4, Batch: 40, Avg. Loss: 0.0004948
# Epoch: 4, Batch: 50, Avg. Loss: 0.0006032
# Epoch: 4, Batch: 60, Avg. Loss: 0.0005098
# Epoch: 4, Batch: 70, Avg. Loss: 0.0005207
# Epoch: 4, Batch: 80, Avg. Loss: 0.0005285
# Epoch: 4, Batch: 90, Avg. Loss: 0.0004813
# Epoch: 4, Batch: 100, Avg. Loss: 0.0005385
# Epoch: 5, Batch: 10, Avg. Loss: 0.0005419
# Epoch: 5, Batch: 20, Avg. Loss: 0.0004328
# Epoch: 5, Batch: 30, Avg. Loss: 0.0004819
# Epoch: 5, Batch: 40, Avg. Loss: 0.0004897
# Epoch: 5, Batch: 50, Avg. Loss: 0.0006713
# Epoch: 5, Batch: 60, Avg. Loss: 0.0004845
# Epoch: 5, Batch: 70, Avg. Loss: 0.0005823
# Epoch: 5, Batch: 80, Avg. Loss: 0.0004988
# Epoch: 5, Batch: 90, Avg. Loss: 0.0005182
# Epoch: 5, Batch: 100, Avg. Loss: 0.0005088
# Epoch: 6, Batch: 10, Avg. Loss: 0.0004020
# Epoch: 6, Batch: 20, Avg. Loss: 0.0003931
# Epoch: 6, Batch: 30, Avg. Loss: 0.0003911
# Epoch: 6, Batch: 40, Avg. Loss: 0.0004578
# Epoch: 6, Batch: 50, Avg. Loss: 0.0004692
# Epoch: 6, Batch: 60, Avg. Loss: 0.0004632
# Epoch: 6, Batch: 70, Avg. Loss: 0.0004770
# Epoch: 6, Batch: 80, Avg. Loss: 0.0005741
# Epoch: 6, Batch: 90, Avg. Loss: 0.0004638
# Epoch: 6, Batch: 100, Avg. Loss: 0.0004750
# Epoch: 7, Batch: 10, Avg. Loss: 0.0004813
# Epoch: 7, Batch: 20, Avg. Loss: 0.0004890
# Epoch: 7, Batch: 30, Avg. Loss: 0.0004350
# Epoch: 7, Batch: 40, Avg. Loss: 0.0004218
# Epoch: 7, Batch: 50, Avg. Loss: 0.0004371
# Epoch: 7, Batch: 60, Avg. Loss: 0.0004128
# Epoch: 7, Batch: 70, Avg. Loss: 0.0004099
# Epoch: 7, Batch: 80, Avg. Loss: 0.0004045
# Epoch: 7, Batch: 90, Avg. Loss: 0.0004519
# Epoch: 7, Batch: 100, Avg. Loss: 0.0004413
# Epoch: 8, Batch: 10, Avg. Loss: 0.0003782
# Epoch: 8, Batch: 20, Avg. Loss: 0.0004454
# Epoch: 8, Batch: 30, Avg. Loss: 0.0004102
# Epoch: 8, Batch: 40, Avg. Loss: 0.0004220
# Epoch: 8, Batch: 50, Avg. Loss: 0.0005183
# Epoch: 8, Batch: 60, Avg. Loss: 0.0003564
# Epoch: 8, Batch: 70, Avg. Loss: 0.0004207
# Epoch: 8, Batch: 80, Avg. Loss: 0.0004295
# Epoch: 8, Batch: 90, Avg. Loss: 0.0005467
# Epoch: 8, Batch: 100, Avg. Loss: 0.0003433
# Epoch: 9, Batch: 10, Avg. Loss: 0.0004193
# Epoch: 9, Batch: 20, Avg. Loss: 0.0004229
# Epoch: 9, Batch: 30, Avg. Loss: 0.0004088
# Epoch: 9, Batch: 40, Avg. Loss: 0.0004179
# Epoch: 9, Batch: 50, Avg. Loss: 0.0003523
# Epoch: 9, Batch: 60, Avg. Loss: 0.0004130
# Epoch: 9, Batch: 70, Avg. Loss: 0.0003709
# Epoch: 9, Batch: 80, Avg. Loss: 0.0004031
# Epoch: 9, Batch: 90, Avg. Loss: 0.0004496
# Epoch: 9, Batch: 100, Avg. Loss: 0.0004436
# Epoch: 10, Batch: 10, Avg. Loss: 0.0003383
# Epoch: 10, Batch: 20, Avg. Loss: 0.0004225
# Epoch: 10, Batch: 30, Avg. Loss: 0.0003588
# Epoch: 10, Batch: 40, Avg. Loss: 0.0004321
# Epoch: 10, Batch: 50, Avg. Loss: 0.0003263
# Epoch: 10, Batch: 60, Avg. Loss: 0.0004867
# Epoch: 10, Batch: 70, Avg. Loss: 0.0003484
# Epoch: 10, Batch: 80, Avg. Loss: 0.0004654
# Epoch: 10, Batch: 90, Avg. Loss: 0.0003550
# Epoch: 10, Batch: 100, Avg. Loss: 0.0004531
# Finished Training

# %%
# train your network
n_epochs = 10 # start small, and increase when you've decided on your model structure and hyperparams

train_net(n_epochs)
# Out:
# CUDA: True
#
# Epoch: 1, Batch: 10, Avg. Loss: 0.0003973
# Epoch: 1, Batch: 20, Avg. Loss: 0.0003619
# Epoch: 1, Batch: 30, Avg. Loss: 0.0003932
# Epoch: 1, Batch: 40, Avg. Loss: 0.0003774
# Epoch: 1, Batch: 50, Avg. Loss: 0.0003603
# Epoch: 1, Batch: 60, Avg. Loss: 0.0003358
# Epoch: 1, Batch: 70, Avg. Loss: 0.0003382
# Epoch: 1, Batch: 80, Avg. Loss: 0.0004443
# Epoch: 1, Batch: 90, Avg. Loss: 0.0003877
# Epoch: 1, Batch: 100, Avg. Loss: 0.0003049
# Epoch: 2, Batch: 10, Avg. Loss: 0.0003599
# Epoch: 2, Batch: 20, Avg. Loss: 0.0003630
# Epoch: 2, Batch: 30, Avg. Loss: 0.0003709
# Epoch: 2, Batch: 40, Avg. Loss: 0.0003454
# Epoch: 2, Batch: 50, Avg. Loss: 0.0004123
# Epoch: 2, Batch: 60, Avg. Loss: 0.0003169
# Epoch: 2, Batch: 70, Avg. Loss: 0.0004530
# Epoch: 2, Batch: 80, Avg. Loss: 0.0003620
# Epoch: 2, Batch: 90, Avg. Loss: 0.0004390
# Epoch: 2, Batch: 100, Avg. Loss: 0.0003773
# Epoch: 3, Batch: 10, Avg. Loss: 0.0003673
# Epoch: 3, Batch: 20, Avg. Loss: 0.0003793
# Epoch: 3, Batch: 30, Avg. Loss: 0.0003297
# Epoch: 3, Batch: 40, Avg. Loss: 0.0003684
# Epoch: 3, Batch: 50, Avg. Loss: 0.0004224
# Epoch: 3, Batch: 60, Avg. Loss: 0.0004032
# Epoch: 3, Batch: 70, Avg. Loss: 0.0004041
# Epoch: 3, Batch: 80, Avg. Loss: 0.0003352
# Epoch: 3, Batch: 90, Avg. Loss: 0.0003522
# Epoch: 3, Batch: 100, Avg. Loss: 0.0003039
# Epoch: 4, Batch: 10, Avg. Loss: 0.0003171
# Epoch: 4, Batch: 20, Avg. Loss: 0.0003643
# Epoch: 4, Batch: 30, Avg. Loss: 0.0003615
# Epoch: 4, Batch: 40, Avg. Loss: 0.0003303
# Epoch: 4, Batch: 50, Avg. Loss: 0.0003232
# Epoch: 4, Batch: 60, Avg. Loss: 0.0003610
# Epoch: 4, Batch: 70, Avg. Loss: 0.0004295
# Epoch: 4, Batch: 80, Avg. Loss: 0.0003870
# Epoch: 4, Batch: 90, Avg. Loss: 0.0003049
# Epoch: 4, Batch: 100, Avg. Loss: 0.0002713
# Epoch: 5, Batch: 10, Avg. Loss: 0.0003775
# Epoch: 5, Batch: 20, Avg. Loss: 0.0003858
# Epoch: 5, Batch: 30, Avg. Loss: 0.0003627
# Epoch: 5, Batch: 40, Avg. Loss: 0.0003705
# Epoch: 5, Batch: 50, Avg. Loss: 0.0002560
# Epoch: 5, Batch: 60, Avg. Loss: 0.0003266
# Epoch: 5, Batch: 70, Avg. Loss: 0.0003313
# Epoch: 5, Batch: 80, Avg. Loss: 0.0003708
# Epoch: 5, Batch: 90, Avg. Loss: 0.0003352
# Epoch: 5, Batch: 100, Avg. Loss: 0.0003344
# Epoch: 6, Batch: 10, Avg. Loss: 0.0002722
# Epoch: 6, Batch: 20, Avg. Loss: 0.0003791
# Epoch: 6, Batch: 30, Avg. Loss: 0.0004832
# Epoch: 6, Batch: 40, Avg. Loss: 0.0003125
# Epoch: 6, Batch: 50, Avg. Loss: 0.0003176
# Epoch: 6, Batch: 60, Avg. Loss: 0.0002779
# Epoch: 6, Batch: 70, Avg. Loss: 0.0003705
# Epoch: 6, Batch: 80, Avg. Loss: 0.0003488
# Epoch: 6, Batch: 90, Avg. Loss: 0.0003019
# Epoch: 6, Batch: 100, Avg. Loss: 0.0003095
# Epoch: 7, Batch: 10, Avg. Loss: 0.0003436
# Epoch: 7, Batch: 20, Avg. Loss: 0.0004056
# Epoch: 7, Batch: 30, Avg. Loss: 0.0003628
# Epoch: 7, Batch: 40, Avg. Loss: 0.0003435
# Epoch: 7, Batch: 50, Avg. Loss: 0.0002891
# Epoch: 7, Batch: 60, Avg. Loss: 0.0003185
# Epoch: 7, Batch: 70, Avg. Loss: 0.0002864
# Epoch: 7, Batch: 80, Avg. Loss: 0.0003183
# Epoch: 7, Batch: 90, Avg. Loss: 0.0002984
# Epoch: 7, Batch: 100, Avg. Loss: 0.0003898
# Epoch: 8, Batch: 10, Avg. Loss: 0.0003182
# Epoch: 8, Batch: 20, Avg. Loss: 0.0003261
# Epoch: 8, Batch: 30, Avg. Loss: 0.0003168
# Epoch: 8, Batch: 40, Avg. Loss: 0.0003003
# Epoch: 8, Batch: 50, Avg. Loss: 0.0003207
# Epoch: 8, Batch: 60, Avg. Loss: 0.0002771
# Epoch: 8, Batch: 70, Avg. Loss: 0.0002874
# Epoch: 8, Batch: 80, Avg. Loss: 0.0003545
# Epoch: 8, Batch: 90, Avg. Loss: 0.0003021
# Epoch: 8, Batch: 100, Avg. Loss: 0.0002951
# Epoch: 9, Batch: 10, Avg. Loss: 0.0002705
# Epoch: 9, Batch: 20, Avg. Loss: 0.0003456
# Epoch: 9, Batch: 30, Avg. Loss: 0.0002605
# Epoch: 9, Batch: 40, Avg. Loss: 0.0002717
# Epoch: 9, Batch: 50, Avg. Loss: 0.0002504
# Epoch: 9, Batch: 60, Avg. Loss: 0.0002944
# Epoch: 9, Batch: 70, Avg. Loss: 0.0002455
# Epoch: 9, Batch: 80, Avg. Loss: 0.0003108
# Epoch: 9, Batch: 90, Avg. Loss: 0.0004335
# Epoch: 9, Batch: 100, Avg. Loss: 0.0003779
# Epoch: 10, Batch: 10, Avg. Loss: 0.0002639
# Epoch: 10, Batch: 20, Avg. Loss: 0.0002835
# Epoch: 10, Batch: 30, Avg. Loss: 0.0002442
# Epoch: 10, Batch: 40, Avg. Loss: 0.0002752
# Epoch: 10, Batch: 50, Avg. Loss: 0.0002980
# Epoch: 10, Batch: 60, Avg. Loss: 0.0003566
# Epoch: 10, Batch: 70, Avg. Loss: 0.0002980
# Epoch: 10, Batch: 80, Avg. Loss: 0.0002403
# Epoch: 10, Batch: 90, Avg. Loss: 0.0003196
# Epoch: 10, Batch: 100, Avg. Loss: 0.0003135
# Finished Training

# %%
# train your network
n_epochs = 10 # start small, and increase when you've decided on your model structure and hyperparams

train_net(n_epochs)
# Out:
# CUDA: True
#
# Epoch: 1, Batch: 10, Avg. Loss: 0.0002395
# Epoch: 1, Batch: 20, Avg. Loss: 0.0003048
# Epoch: 1, Batch: 30, Avg. Loss: 0.0003275
# Epoch: 1, Batch: 40, Avg. Loss: 0.0002596
# Epoch: 1, Batch: 50, Avg. Loss: 0.0003440
# Epoch: 1, Batch: 60, Avg. Loss: 0.0002880
# Epoch: 1, Batch: 70, Avg. Loss: 0.0004809
# Epoch: 1, Batch: 80, Avg. Loss: 0.0002769
# Epoch: 1, Batch: 90, Avg. Loss: 0.0002841
# Epoch: 1, Batch: 100, Avg. Loss: 0.0002575
# Epoch: 2, Batch: 10, Avg. Loss: 0.0002119
# Epoch: 2, Batch: 20, Avg. Loss: 0.0002551
# Epoch: 2, Batch: 30, Avg. Loss: 0.0002502
# Epoch: 2, Batch: 40, Avg. Loss: 0.0002494
# Epoch: 2, Batch: 50, Avg. Loss: 0.0002659
# Epoch: 2, Batch: 60, Avg. Loss: 0.0002822
# Epoch: 2, Batch: 70, Avg. Loss: 0.0002488
# Epoch: 2, Batch: 80, Avg. Loss: 0.0002970
# Epoch: 2, Batch: 90, Avg. Loss: 0.0003775
# Epoch: 2, Batch: 100, Avg. Loss: 0.0003203
# Epoch: 3, Batch: 10, Avg. Loss: 0.0002559
# Epoch: 3, Batch: 20, Avg. Loss: 0.0002697
# Epoch: 3, Batch: 30, Avg. Loss: 0.0003045
# Epoch: 3, Batch: 40, Avg. Loss: 0.0002722
# Epoch: 3, Batch: 50, Avg. Loss: 0.0003713
# Epoch: 3, Batch: 60, Avg. Loss: 0.0002487
# Epoch: 3, Batch: 70, Avg. Loss: 0.0002991
# Epoch: 3, Batch: 80, Avg. Loss: 0.0003303
# Epoch: 3, Batch: 90, Avg. Loss: 0.0002820
# Epoch: 3, Batch: 100, Avg. Loss: 0.0003457
# Epoch: 4, Batch: 10, Avg. Loss: 0.0002543
# Epoch: 4, Batch: 20, Avg. Loss: 0.0002849
# Epoch: 4, Batch: 30, Avg. Loss: 0.0002430
# Epoch: 4, Batch: 40, Avg. Loss: 0.0003112
# Epoch: 4, Batch: 50, Avg. Loss: 0.0004084
# Epoch: 4, Batch: 60, Avg. Loss: 0.0002298
# Epoch: 4, Batch: 70, Avg. Loss: 0.0002434
# Epoch: 4, Batch: 80, Avg. Loss: 0.0002921
# Epoch: 4, Batch: 90, Avg. Loss: 0.0002220
# Epoch: 4, Batch: 100, Avg. Loss: 0.0003120
# Epoch: 5, Batch: 10, Avg. Loss: 0.0003105
# Epoch: 5, Batch: 20, Avg. Loss: 0.0002717
# Epoch: 5, Batch: 30, Avg. Loss: 0.0003230
# Epoch: 5, Batch: 40, Avg. Loss: 0.0002693
# Epoch: 5, Batch: 50, Avg. Loss: 0.0003166
# Epoch: 5, Batch: 60, Avg. Loss: 0.0002599
# Epoch: 5, Batch: 70, Avg. Loss: 0.0003520
# Epoch: 5, Batch: 80, Avg. Loss: 0.0002837
# Epoch: 5, Batch: 90, Avg. Loss: 0.0002388
# Epoch: 5, Batch: 100, Avg. Loss: 0.0002248
# Epoch: 6, Batch: 10, Avg. Loss: 0.0002200
# Epoch: 6, Batch: 20, Avg. Loss: 0.0002755
# Epoch: 6, Batch: 30, Avg. Loss: 0.0002335
# Epoch: 6, Batch: 40, Avg. Loss: 0.0002528
# Epoch: 6, Batch: 50, Avg. Loss: 0.0003555
# Epoch: 6, Batch: 60, Avg. Loss: 0.0002513
# Epoch: 6, Batch: 70, Avg. Loss: 0.0002507
# Epoch: 6, Batch: 80, Avg. Loss: 0.0002624
# Epoch: 6, Batch: 90, Avg. Loss: 0.0003480
# Epoch: 6, Batch: 100, Avg. Loss: 0.0002793
# Epoch: 7, Batch: 10, Avg. Loss: 0.0002535
# Epoch: 7, Batch: 20, Avg. Loss: 0.0003873
# Epoch: 7, Batch: 30, Avg. Loss: 0.0002259
# Epoch: 7, Batch: 40, Avg. Loss: 0.0002359
# Epoch: 7, Batch: 50, Avg. Loss: 0.0001995
# Epoch: 7, Batch: 60, Avg. Loss: 0.0002550
# Epoch: 7, Batch: 70, Avg. Loss: 0.0002967
# Epoch: 7, Batch: 80, Avg. Loss: 0.0002523
# Epoch: 7, Batch: 90, Avg. Loss: 0.0002535
# Epoch: 7, Batch: 100, Avg. Loss: 0.0002824
# Epoch: 8, Batch: 10, Avg. Loss: 0.0002786
# Epoch: 8, Batch: 20, Avg. Loss: 0.0002428
# Epoch: 8, Batch: 30, Avg. Loss: 0.0002455
# Epoch: 8, Batch: 40, Avg. Loss: 0.0002228
# Epoch: 8, Batch: 50, Avg. Loss: 0.0002126
# Epoch: 8, Batch: 60, Avg. Loss: 0.0003555
# Epoch: 8, Batch: 70, Avg. Loss: 0.0002597
# Epoch: 8, Batch: 80, Avg. Loss: 0.0002179
# Epoch: 8, Batch: 90, Avg. Loss: 0.0002432
# Epoch: 8, Batch: 100, Avg. Loss: 0.0002354
# Epoch: 9, Batch: 10, Avg. Loss: 0.0002230
# Epoch: 9, Batch: 20, Avg. Loss: 0.0002692
# Epoch: 9, Batch: 30, Avg. Loss: 0.0002502
# Epoch: 9, Batch: 40, Avg. Loss: 0.0003532
# Epoch: 9, Batch: 50, Avg. Loss: 0.0003013
# Epoch: 9, Batch: 60, Avg. Loss: 0.0002567
# Epoch: 9, Batch: 70, Avg. Loss: 0.0002561
# Epoch: 9, Batch: 80, Avg. Loss: 0.0002403
# Epoch: 9, Batch: 90, Avg. Loss: 0.0002785
# Epoch: 9, Batch: 100, Avg. Loss: 0.0002030
# Epoch: 10, Batch: 10, Avg. Loss: 0.0002335
# Epoch: 10, Batch: 20, Avg. Loss: 0.0002661
# Epoch: 10, Batch: 30, Avg. Loss: 0.0002258
# Epoch: 10, Batch: 40, Avg. Loss: 0.0002402
# Epoch: 10, Batch: 50, Avg. Loss: 0.0002178
# Epoch: 10, Batch: 60, Avg. Loss: 0.0002209
# Epoch: 10, Batch: 70, Avg. Loss: 0.0002703
# Epoch: 10, Batch: 80, Avg. Loss: 0.0003004
# Epoch: 10, Batch: 90, Avg. Loss: 0.0003274
# Epoch: 10, Batch: 100, Avg. Loss: 0.0003330
# Finished Training

# %%
# train your network
n_epochs = 10 # start small, and increase when you've decided on your model structure and hyperparams

train_net(n_epochs)
# Out:
# CUDA: True
#
# Epoch: 1, Batch: 10, Avg. Loss: 0.0002932
# Epoch: 1, Batch: 20, Avg. Loss: 0.0003604
# Epoch: 1, Batch: 30, Avg. Loss: 0.0002316
# Epoch: 1, Batch: 40, Avg. Loss: 0.0002468
# Epoch: 1, Batch: 50, Avg. Loss: 0.0003171
# Epoch: 1, Batch: 60, Avg. Loss: 0.0002881
# Epoch: 1, Batch: 70, Avg. Loss: 0.0002646
# Epoch: 1, Batch: 80, Avg. Loss: 0.0002765
# Epoch: 1, Batch: 90, Avg. Loss: 0.0002498
# Epoch: 1, Batch: 100, Avg. Loss: 0.0002444
# Epoch: 2, Batch: 10, Avg. Loss: 0.0002025
# Epoch: 2, Batch: 20, Avg. Loss: 0.0002378
# Epoch: 2, Batch: 30, Avg. Loss: 0.0002269
# Epoch: 2, Batch: 40, Avg. Loss: 0.0002045
# Epoch: 2, Batch: 50, Avg. Loss: 0.0002453
# Epoch: 2, Batch: 60, Avg. Loss: 0.0002884
# Epoch: 2, Batch: 70, Avg. Loss: 0.0002159
# Epoch: 2, Batch: 80, Avg. Loss: 0.0002337
# Epoch: 2, Batch: 90, Avg. Loss: 0.0002974
# Epoch: 2, Batch: 100, Avg. Loss: 0.0002193
# Epoch: 3, Batch: 10, Avg. Loss: 0.0002121
# Epoch: 3, Batch: 20, Avg. Loss: 0.0002746
# Epoch: 3, Batch: 30, Avg. Loss: 0.0003046
# Epoch: 3, Batch: 40, Avg. Loss: 0.0002370
# Epoch: 3, Batch: 50, Avg. Loss: 0.0003188
# Epoch: 3, Batch: 60, Avg. Loss: 0.0002662
# Epoch: 3, Batch: 70, Avg. Loss: 0.0002790
# Epoch: 3, Batch: 80, Avg. Loss: 0.0002100
# Epoch: 3, Batch: 90, Avg. Loss: 0.0002149
# Epoch: 3, Batch: 100, Avg. Loss: 0.0002599
# Epoch: 4, Batch: 10, Avg. Loss: 0.0002190
# Epoch: 4, Batch: 20, Avg. Loss: 0.0003490
# Epoch: 4, Batch: 30, Avg. Loss: 0.0002642
# Epoch: 4, Batch: 40, Avg. Loss: 0.0002017
# Epoch: 4, Batch: 50, Avg. Loss: 0.0003084
# Epoch: 4, Batch: 60, Avg. Loss: 0.0002173
# Epoch: 4, Batch: 70, Avg. Loss: 0.0002694
# Epoch: 4, Batch: 80, Avg. Loss: 0.0002396
# Epoch: 4, Batch: 90, Avg. Loss: 0.0002534
# Epoch: 4, Batch: 100, Avg. Loss: 0.0002184
# Epoch: 5, Batch: 10, Avg. Loss: 0.0002925
# Epoch: 5, Batch: 20, Avg. Loss: 0.0002083
# Epoch: 5, Batch: 30, Avg. Loss: 0.0002158
# Epoch: 5, Batch: 40, Avg. Loss: 0.0002697
# Epoch: 5, Batch: 50, Avg. Loss: 0.0002790
# Epoch: 5, Batch: 60, Avg. Loss: 0.0002535
# Epoch: 5, Batch: 70, Avg. Loss: 0.0002050
# Epoch: 5, Batch: 80, Avg. Loss: 0.0002517
# Epoch: 5, Batch: 90, Avg. Loss: 0.0003193
# Epoch: 5, Batch: 100, Avg. Loss: 0.0002842
# Epoch: 6, Batch: 10, Avg. Loss: 0.0001821
# Epoch: 6, Batch: 20, Avg. Loss: 0.0002166
# Epoch: 6, Batch: 30, Avg. Loss: 0.0001890
# Epoch: 6, Batch: 40, Avg. Loss: 0.0002053
# Epoch: 6, Batch: 50, Avg. Loss: 0.0002118
# Epoch: 6, Batch: 60, Avg. Loss: 0.0002568
# Epoch: 6, Batch: 70, Avg. Loss: 0.0002240
# Epoch: 6, Batch: 80, Avg. Loss: 0.0002015
# Epoch: 6, Batch: 90, Avg. Loss: 0.0002147
# Epoch: 6, Batch: 100, Avg. Loss: 0.0002304
# Epoch: 7, Batch: 10, Avg. Loss: 0.0002569
# Epoch: 7, Batch: 20, Avg. Loss: 0.0002424
# Epoch: 7, Batch: 30, Avg. Loss: 0.0001932
# Epoch: 7, Batch: 40, Avg. Loss: 0.0002182
# Epoch: 7, Batch: 50, Avg. Loss: 0.0002733
# Epoch: 7, Batch: 60, Avg. Loss: 0.0002102
# Epoch: 7, Batch: 70, Avg. Loss: 0.0001957
# Epoch: 7, Batch: 80, Avg. Loss: 0.0002501
# Epoch: 7, Batch: 90, Avg. Loss: 0.0002006
# Epoch: 7, Batch: 100, Avg. Loss: 0.0002546
# Epoch: 8, Batch: 10, Avg. Loss: 0.0001987
# Epoch: 8, Batch: 20, Avg. Loss: 0.0002021
# Epoch: 8, Batch: 30, Avg. Loss: 0.0001965
# Epoch: 8, Batch: 40, Avg. Loss: 0.0001926
# Epoch: 8, Batch: 50, Avg. Loss: 0.0001923
# Epoch: 8, Batch: 60, Avg. Loss: 0.0002664
# Epoch: 8, Batch: 70, Avg. Loss: 0.0002790
# Epoch: 8, Batch: 80, Avg. Loss: 0.0002512
# Epoch: 8, Batch: 90, Avg. Loss: 0.0002202
# Epoch: 8, Batch: 100, Avg. Loss: 0.0001715
# Epoch: 9, Batch: 10, Avg. Loss: 0.0002062
# Epoch: 9, Batch: 20, Avg. Loss: 0.0002232
# Epoch: 9, Batch: 30, Avg. Loss: 0.0002501
# Epoch: 9, Batch: 40, Avg. Loss: 0.0002422
# Epoch: 9, Batch: 50, Avg. Loss: 0.0002329
# Epoch: 9, Batch: 60, Avg. Loss: 0.0001762
# Epoch: 9, Batch: 70, Avg. Loss: 0.0001842
# Epoch: 9, Batch: 80, Avg. Loss: 0.0002423
# Epoch: 9, Batch: 90, Avg. Loss: 0.0003485
# Epoch: 9, Batch: 100, Avg. Loss: 0.0001971
# Epoch: 10, Batch: 10, Avg. Loss: 0.0002263
# Epoch: 10, Batch: 20, Avg. Loss: 0.0003173
# Epoch: 10, Batch: 30, Avg. Loss: 0.0002230
# Epoch: 10, Batch: 40, Avg. Loss: 0.0001770
# Epoch: 10, Batch: 50, Avg. Loss: 0.0001967
# Epoch: 10, Batch: 60, Avg. Loss: 0.0002138
# Epoch: 10, Batch: 70, Avg. Loss: 0.0002149
# Epoch: 10, Batch: 80, Avg. Loss: 0.0002231
# Epoch: 10, Batch: 90, Avg. Loss: 0.0001649
# Epoch: 10, Batch: 100, Avg. Loss: 0.0002743
# Finished Training

# %% [markdown]
# ## Test data
#
# See how your model performs on previously unseen, test data. We've already loaded and transformed this data, similar to the training data. Next, run your trained model on these images to see what kind of keypoints are produced. You should be able to see if your model is fitting each new face it sees, if the points are distributed randomly, or if the points have actually overfitted the training data and do not generalize.

# %%
# get a sample of test data again
net.eval()
test_images, test_outputs, gt_pts = net_sample_output()

print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([16, 1, 224, 224])
# torch.Size([16, 68, 2])
# torch.Size([16, 68, 2])

# %%
## TODO: visualize your test output
# you can use the same function as before, by un-commenting the line below:

visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# Once you've found a good model (or two), save your model so you can load it and use it later!

# %%
## TODO: change the name to something uniqe for each new model
model_dir = 'saved_models/'
model_name = 'keypoints_model_1.pt'

# after training, save your model parameters in the dir 'saved_models'
torch.save(net.state_dict(), model_dir+model_name)

# %% [markdown]
# After you've trained a well-performing model, answer the following questions so that we have some insight into your training and architecture selection process. Answering all questions is required to pass this project.

# %% [markdown]
# ### Question 1: What optimization and loss functions did you choose and why?

# %% [markdown]
# **Answer**:
#
# I choose a loss function as `nn.SmoothL1Loss()` due to the fact that it is less sensitive to outliers than the MSELoss and in some cases prevents exploding gradients. [[ref]](https://pytorch.org/docs/stable/nn.html#torch.nn.SmoothL1Loss)
#
# I choose an optimizer as `optim.Adam()` with `0.0001` learning rate. Its computation is very efficient and it is good to solve with large data. Also, it is appropriate for problems with noisy and sparse gradients.

# %% [markdown]
# ### Question 2: What kind of network architecture did you start with and how did it change as you tried different architectures? Did you decide to add more convolutional layers or any layers to avoid overfitting the data?

# %% [markdown]
# **Answer**:
#
# I started with LeNet architecture, but it showed unsatisfied result. That is why I built a network using 4 convolution layers. Each convolution layer applied with a kernel size of 5 and filter sizes of 32, 64, 128 and 256. All of them had a kernel size of 2 and a stride of 1, and 0.5 dropout rate. After that, first fully connected layer applied with output sizes of 1000 and 0.5 dropout rate, then sencond fully connected layer applied with output sizes of 136.
#
# I initialize with the weights of convolution layers by performing Xavier initialization so that a particular input signal does not get too big or too small as the network trains. I set up the biases of convolution layers by float 0.

# %% [markdown]
# ### Question 3: How did you decide on the number of epochs and batch_size to train your model?

# %% [markdown]
# **Answer**:
#
# First I tried to train with default number, the batch size of 10 and the number of epochs 1. Then, I increased the number of epochs until 10, also I trained more 10 epochs until the total number of 50. But, it took a long time on CPU, so I changed a running environment with GPU. After that, I was increasing the batch size at 16, 32 and 64, and I choose 32 that it looked a suitable to train with my model.

# %% [markdown]
# ## Feature Visualization
#
# Sometimes, neural networks are thought of as a black box, given some input, they learn to produce some output. CNN's are actually learning to recognize a variety of spatial patterns and you can visualize what each convolutional layer has been trained to recognize by looking at the weights that make up each convolutional kernel and applying those one at a time to a sample image. This technique is called feature visualization and it's useful for understanding the inner workings of a CNN.

# %% [markdown]
# In the cell below, you can see how to extract a single filter (by index) from your first convolutional layer. The filter should appear as a grayscale grid.

# %%
# Get the weights in the first conv layer, "conv1"
# if necessary, change this to reflect the name of your first conv layer
weights1 = net.conv1.weight.data
if torch.cuda.is_available():
    w = weights1.cpu().numpy()
else:
    w = weights.numpy()

fig = plt.figure(figsize=(8,20))
for filter_index in range(w.shape[0]):
    ax = fig.add_subplot(8, 4, filter_index+1)
    ax.title.set_text('Layer #{}'.format(filter_index+1))
    plt.imshow(w[filter_index][0], cmap='gray')

# %% [markdown]
# ## Feature maps
#
# Each CNN has at least one convolutional layer that is composed of stacked filters (also known as convolutional kernels). As a CNN trains, it learns what weights to include in it's convolutional kernels and when these kernels are applied to some input image, they produce a set of **feature maps**. So, feature maps are just sets of filtered images; they are the images produced by applying a convolutional kernel to an input image. These maps show us the features that the different layers of the neural network learn to extract. For example, you might imagine a convolutional kernel that detects the vertical edges of a face or another one that detects the corners of eyes. You can see what kind of features each of these kernels detects by applying them to an image. One such example is shown below; from the way it brings out the lines in an the image, you might characterize this as an edge detection filter.
#
# <img src='images/feature_map_ex.png' width=50% height=50%/>
#
#
# Next, choose a test image and filter it with one of the convolutional kernels in your trained CNN; look at the filtered output to get an idea what that particular kernel detects.
#
# ### TODO: Filter an image to see the effect of a convolutional kernel
# ---

# %%
##TODO: load in and display any image from the transformed test dataset

## TODO: Using cv's filter2D function,
## apply a specific set of filter weights (like the one displayed above) to the test image
import cv2

test_images, test_outputs, gt_pts = net_sample_output()

idx = np.random.randint(0, len(test_images))
img = test_images[idx].data
if torch.cuda.is_available():
    img = img.cpu().numpy()
else:
    img = img.numpy()
img = np.transpose(img, (1, 2, 0))

fig = plt.figure(figsize=(20, 20))
ax = plt.subplot(1, 5, 1)
print('Image index: {}'.format(idx))
print(img.shape)

plt.imshow(np.squeeze(img),cmap='gray')
for i in range(4):
    img_filtered = cv2.filter2D(img, -1, w[i][0])
    ax = plt.subplot(1, 5, i+2)
    ax.title.set_text('Conv{}'.format(i+1))
    plt.imshow(img_filtered, cmap='gray')
plt.show()
# Out:
# Image index: 14
# (224, 224, 1)

# %% [markdown]
# ### Question 4: Choose one filter from your trained CNN and apply it to a test image; what purpose do you think it plays? What kind of feature do you think it detects?

# %% [markdown]
# **Answer**:
#
# It showed every convolution layers how to change with an intensity of the color. The Conv1 layer, for example, emphasized the edges of person and other background objects. The Conv4 layer inversed the color of images.

# %% [markdown]
# ---
# ## Moving on!
#
# Now that you've defined and trained your model (and saved the best model), you are ready to move on to the last notebook, which combines a face detector with your saved model to create a facial keypoint detection system that can predict the keypoints on *any* face in an image!
